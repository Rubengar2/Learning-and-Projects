# %% [markdown]
# # 🌍 Exploratory Data Analysis of the dataset 🏆
# # "The Top 10 Individual Performances in FIFA World Cup History"
#
# ## Introduction
# In this notebook, we will embark on an exciting journey to uncover the hidden gems of the FIFA World Cup history! We'll dive deep into the data to discover the legendary performances that have shaped the beautiful game.
#
# ## Description of the dataset<a id="dataset-description"></a>
# The dataset comprises detailed statistics of players who graced the FIFA World Cup stage, handpicked from the top three performers of each victorious national team across editions. This means that while iconic players from certain editions who didn't clinch the title won't be considered, we're bound to uncover the brilliance of those who led their nations to glory! 🌟
#
# For instance, names like Pelé, Maradona, and Zidane would undoubtedly make the cut, whereas other legendary figures like Johan Cruyff or Michel Platini might not, given their teams' fate in their respective tournaments.
#
# ## Exploratory Data Analysis<a id="exploratory-analysis"></a>
# Our journey begins with an in-depth exploration of the dataset, where we'll analyze various aspects of player performance in the FIFA World Cup to get some relevant insights in order

# %% [markdown]
# ## Description of dataset features
#
# - **goals**: Number of goals scored by the player.
# - **yellowCards**: Number of yellow cards received by the player.
# - **redCards**: Number of red cards received by the player.
# - **groundDuelsWon**: Number of ground duels won by the player.
# - **groundDuelsWonPercentage**: Percentage of ground duels won by the player.
# - **aerialDuelsWon**: Number of aerial duels won by the player.
# - **aerialDuelsWonPercentage**: Percentage of aerial duels won by the player.
# - **successfulDribbles**: Number of successful dribbles by the player.
# - **successfulDribblesPercentage**: Percentage of successful dribbles by the player.
# - **tackles**: Number of tackles made by the player.
# - **assists**: Number of assists made by the player.
# - **accuratePassesPercentage**: Percentage of accurate passes made by the player.
# - **totalDuelsWon**: Total number of duels won by the player.
# - **totalDuelsWonPercentage**: Percentage of total duels won by the player.
# - **minutesPlayed**: Number of minutes played by the player.
# - **wasFouled**: Number of times the player was fouled.
# - **fouls**: Number of fouls committed by the player.
# - **dispossessed**: Number of times the player lost possession of the ball.
# - **appearances**: Number of appearances of the player in the tournament.
# - **saves**: Number of shots saved by the goalkeeper.
# - **savedShotsFromInsideTheBox**: Number of shots saved by the goalkeeper from inside the box.
# - **savedShotsFromOutsideTheBox**: Number of shots saved by the goalkeeper from outside the box.
# - **goalsConcededInsideTheBox**: Number of goals conceded by the goalkeeper from inside the box.
# - **goalsConcededOutsideTheBox**: Number of goals conceded by the goalkeeper from outside the box.
# - **highClaims**: Number of high claims made by the goalkeeper.
# - **successfulRunsOut**: Number of successful runs out by the goalkeeper.
# - **punches**: Number of punches made by the goalkeeper.
# - **runsOut**: Number of runs out by the goalkeeper.
# - **accurateFinalThirdPasses**: Number of accurate passes made by the player in the final third of the pitch.
# - **bigChancesCreated**: Number of big chances created by the player.
# - **accuratePasses**: Number of accurate passes made by the player.
# - **keyPasses**: Number of key passes made by the player.
# - **accurateCrosses**: Number of accurate crosses made by the player.
# - **accurateCrossesPercentage**: Percentage of accurate crosses made by the player.
# - **accurateLongBalls**: Number of accurate long balls made by the player.
# - **accurateLongBallsPercentage**: Percentage of accurate long balls made by the player.
# - **interceptions**: Number of interceptions made by the player.
# - **clearances**: Number of clearances made by the player.
# - **dribbledPast**: Number of times the player was dribbled past by an opponent.
# - **bigChancesMissed**: Number of big chances missed by the player.
# - **totalShots**: Total number of shots taken by the player.
# - **shotsOnTarget**: Number of shots on target taken by the player.
# - **blockedShots**: Number of shots blocked by defenders.
# - **goalConversionPercentage**: Percentage of shots converted into goals by the player.
# - **hitWoodwork**: Number of shots that hit the woodwork (post or crossbar).
# - **offsides**: Number of times the player was offside.
# - **expectedGoals**: Number of expected goals based on the quality of shot opportunities.
# - **errorLeadToGoal**: Number of errors leading to a goal by the opposing team.
# - **errorLeadToShot**: Number of errors leading to a shot by the opposing team.
# - **passToAssist**: Number of passes resulting in an assist for a goal.
# - **player**: Name of the player.
# - **team**: Team to which the player belongs.
# - **year**: Year of the World Cup.

# %% [markdown]
# # Before Analysis
# I just will plot some stats and information to validate that every thing it is good with the data extracted and the values. This information will be necessary to avoid act with bias in some cases. Missing data, not complete data or dealing with different formats.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FWC_stats.csv')
df.tail()
# Out:
#     goals  yellowCards  redCards  groundDuelsWon  groundDuelsWonPercentage  \
# 40      3            1         0              41                     57.75
# 41      7            0         0              78                     60.94
# 42      4            0         0              11                     32.35
# 43      3            0         0              36                     52.17
# 44      1            1         0              30                     53.57
#
#     aerialDuelsWon  aerialDuelsWonPercentage  successfulDribbles  \
# 40               0                      0.00                  19
# 41               1                     50.00                  47
# 42               8                     61.54                   5
# 43               3                     60.00                  12
# 44               8                     88.89                   5
#
#     successfulDribblesPercentage  tackles  ...  goalConversionPercentage  \
# ...

# %%
df.columns
# Out:
# Index(['goals', 'yellowCards', 'redCards', 'groundDuelsWon',
#        'groundDuelsWonPercentage', 'aerialDuelsWon',
#        'aerialDuelsWonPercentage', 'successfulDribbles',
#        'successfulDribblesPercentage', 'tackles', 'assists',
#        'accuratePassesPercentage', 'totalDuelsWon', 'totalDuelsWonPercentage',
#        'minutesPlayed', 'wasFouled', 'fouls', 'dispossessed', 'appearances',
#        'saves', 'savedShotsFromInsideTheBox', 'savedShotsFromOutsideTheBox',
#        'goalsConcededInsideTheBox', 'goalsConcededOutsideTheBox', 'highClaims',
#        'successfulRunsOut', 'punches', 'runsOut', 'accurateFinalThirdPasses',
#        'bigChancesCreated', 'accuratePasses', 'keyPasses', 'accurateCrosses',
#        'accurateCrossesPercentage', 'accurateLongBalls',
#        'accurateLongBallsPercentage', 'interceptions', 'clearances',
#        'dribbledPast', 'bigChancesMissed', 'totalShots', 'shotsOnTarget',
# ...

# %% [markdown]
# ## Dataset Description
# This dataset contains performance statistics of football players across the FIFA WC tournament since 1966 to 2022.
#
# ### Overview
# - **Number of Players**:
#   - The dataset includes a total of 45 players.
#
# - **Years Considered**:
#   - The dataset covers matches from 1966 to 2022.
#     Please note that data before 1962 has been excluded due to the lack of clear statistics. Unfortunatelly we wont see good players as Luis Suarez, Garrincha, Didi or the first WC champions (30's and 50's)
#
# - **Scope**:
#   - Defensive and goalkeeper statistics have been omitted to focus on outfield player performance.
#     This decision was made to provide clarity in analysis and avoid biases.
#     However, an analysis focusing on defenders and goalkeepers can be conducted separately for a comprehensive understanding of team performance.

# %% [markdown]
# ## Data Preprocessing
# - The dataset has undergone preprocessing to remove goalkeeper-specific variables, as well as any incomplete or redundant data points.
# - Missing values and outliers have been addressed to ensure data quality and reliability.

# %%
# List of goalkeeper-specific variables
goalkeeper_variables = ['saves', 'savedShotsFromInsideTheBox', 'savedShotsFromOutsideTheBox',
                        'goalsConcededInsideTheBox', 'goalsConcededOutsideTheBox', 'highClaims',
                        'punches']

# Drop the goalkeeper-specific variables from the DataFrame
df = df.drop(goalkeeper_variables, axis=1)

# Display the resulting DataFrame
df.head()
# Out:
#    goals  yellowCards  redCards  groundDuelsWon  groundDuelsWonPercentage  \
# 0      7            1         0              40                     45.98
# 1      1            0         0              23                     58.97
# 2      1            1         0              31                     55.36
# 3      4            0         0              29                     50.00
# 4      4            2         0              52                     59.09
#
#    aerialDuelsWon  aerialDuelsWonPercentage  successfulDribbles  \
# 0               4                     36.36                  15
# 1               0                      0.00                  13
# 2               9                     75.00                   3
# 3               5                     41.67                   8
# 4               2                     28.57                  32
#
#    successfulDribblesPercentage  tackles  ...  goalConversionPercentage  \
# ...

# %%
# Create a new column 'Player_Year' by concatenating 'Player' and 'Year' columns to get better information in the future charts
df['Player_Year'] = df['player'] + ' - ' + df['year'].astype(str)

# Display the updated DataFrame
df.head()
# Out:
#    goals  yellowCards  redCards  groundDuelsWon  groundDuelsWonPercentage  \
# 0      7            1         0              40                     45.98
# 1      1            0         0              23                     58.97
# 2      1            1         0              31                     55.36
# 3      4            0         0              29                     50.00
# 4      4            2         0              52                     59.09
#
#    aerialDuelsWon  aerialDuelsWonPercentage  successfulDribbles  \
# 0               4                     36.36                  15
# 1               0                      0.00                  13
# 2               9                     75.00                   3
# 3               5                     41.67                   8
# 4               2                     28.57                  32
#
#    successfulDribblesPercentage  tackles  ...  hitWoodwork  offsides  \
# ...

# %%
# Dictionary of color palettes for each World Cup-winning country from 1966 to 2022
paletas_paises_campeones = {
    'Brazil': ['#00843D', '#FFD700', '#00529C'],  # Green, Yellow, Blue
    'Germany': ['#000000', '#D3D3D3', '#0000FF', '#FF0000'],  # Black, Gray, Blue, Red
    'Italy': ['#00529C', '#FFFFFF', '#FF0000'],  # Green, White, Red
    'Argentina': ['#75AADB', '#F6D200', '#FFFFFF'],  # Sky Blue, Yellow, White
    'France': ['#0055A4', '#FFFFFF', '#EF4135'],  # Blue, White, Red
    'Uruguay': ['#75AADB', '#FFFFFF', '#FF0000'],  # Sky Blue, White, Red
    'England': ['#CC0000', '#FFFFFF', '#CC0000'],  # Blue, White, Red
    'Spain': ['#FF0000', '#FF0000', '#FFFF00'],  # Orange, Red, Yellow
    'West Germany' : ['#000000', '#D3D3D3', '#0000FF', '#FF0000'],  # Black, Gray, Blue, Red
}

# Save color palettes to a JSON file
import json

with open('paletas_paises_campeones.json', 'w') as file:
    json.dump(paletas_paises_campeones, file)

print("Color palettes saved successfully to 'paletas_paises_campeones.json'")
# Out:
# Color palettes saved successfully to 'paletas_paises_campeones.json'

# %% [markdown]
# ### **Fundamental Insights**

# %% [markdown]
# ### Most goals in WC edition

# %%
# Sort the DataFrame by the 'goals' column in descending order and take only the top 10 rows
df_top_10_goals = df.sort_values(by='goals', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='goals', y='Player_Year', hue='team', data=df_top_10_goals, palette=team_colors, legend=False)

# Add the value inside each bar
for index, value in enumerate(df_top_10_goals['goals']):
    plt.text(value, index, str(value), va='center', ha='right', color='white', fontsize=11)

# Customize the plot
plt.xlabel('Goals')
plt.ylabel('Player - Year')
plt.title('Top 10 Goal Scorers per Edition of FIFA World Cup')

# Show the plot
plt.show()

# %% [markdown]
# ### Most assist provided in a WC edition

# %%
# Sort the DataFrame by the 'assists' column in descending order and take only the top 10 rows
df_top_10_assists = df.sort_values(by='assists', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='assists', y='Player_Year', hue='team', data=df_top_10_assists, palette=team_colors, legend=False)

# Add the value inside each bar
for index, value in enumerate(df_top_10_assists['assists']):
    plt.text(value, index, str(value), va='center', ha='right', color='white', fontsize=11)

# Customize the plot
plt.xlabel('Assists')
plt.ylabel('Player - Year')
plt.title('Top 10 Assist Providers per Edition of FIFA World Cup')

# Show the plot
plt.show()

# %% [markdown]
# ### G + A , GOALS + ASSISTS

# %%
# Calculate the sum of goals and assists and create a new column 'g+a'
df['g+a'] = df['goals'] + df['assists']

# %%
# Sort the DataFrame by the 'g+a' column in descending order and take only the top 10 rows
df_top_10_ga = df.sort_values(by='g+a', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='g+a', y='Player_Year', hue='team', data=df_top_10_ga, palette=team_colors, legend=False)

# Add the value inside each bar
for index, value in enumerate(df_top_10_ga['g+a']):
    plt.text(value, index, str(value), va='center', ha='right', color='white', fontsize=11)

# Customize the plot
plt.xlabel('Goals + Assists')
plt.ylabel('Player - Year')
plt.title('Top 10 Players by Goals + Assists per Edition of FIFA World Cup')

# Show the plot
plt.show()

# %% [markdown]
# ### Most fouls Received

# %%
# Sort the DataFrame by the 'wasFouled' column in descending order and take only the top 10 rows
df_top_10_was_fouled = df.sort_values(by='wasFouled', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='wasFouled', y='Player_Year', hue='team', data=df_top_10_was_fouled, palette=team_colors, legend=False)

# Add the value inside each bar
for index, value in enumerate(df_top_10_was_fouled['wasFouled']):
    plt.text(value, index, str(value), va='center', ha='right', color='white', fontsize=11)

# Customize the plot
plt.xlabel('Was Fouled')
plt.ylabel('Player - Year')
plt.title('Top 10 Players by "Was Fouled" per Edition of FIFA World Cup')

# Show the plot
plt.show()

# %%
# Sort the DataFrame by the 'wasFouled' column in descending order and take only the top 10 rows
df_top_10_was_fouled = df.sort_values(by='wasFouled', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='wasFouled', y='Player_Year', data=df_top_10_was_fouled, color='skyblue', label='Was Fouled')
sns.barplot(x='fouls', y='Player_Year', data=df_top_10_was_fouled, color='orange', label='Fouls Committed')

# Customize the plot
plt.xlabel('Number of Fouls')
plt.ylabel('Player - Year')
plt.title('Top 10 Players by "Was Fouled" and "Fouls Committed" per Edition of FIFA World Cup')
plt.legend()

# Show the plot
plt.show()

# %%
# Sort the DataFrame by the 'wasFouled' column in descending order and take only the top 10 rows
df_top_10_dribbles = df.sort_values(by='successfulDribbles', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='successfulDribbles', y='Player_Year', data=df_top_10_dribbles, color='skyblue', label='Successful Dribbles')
sns.barplot(x='wasFouled', y='Player_Year', data=df_top_10_dribbles, color='orange', label='Was Fouled')

# Customize the plot
plt.xlabel('Number of Successful Dribbles and Was Fouled')
plt.ylabel('Player - Year')
plt.title('Top 10 Players by "Successful Dribbles" and "Was Fouled" per Edition of FIFA World Cup')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Pass stats

# %%
# Sort the DataFrame by the 'accuratePassesPercentage' column in descending order and take only the top 10 rows
df_top_10_pass_percentage = df.sort_values(by='accuratePassesPercentage', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='accuratePassesPercentage', y='Player_Year', hue='team', data=df_top_10_pass_percentage, palette=team_colors, legend=False)

# Add the value inside each bar
for index, value in enumerate(df_top_10_pass_percentage['accuratePassesPercentage']):
    plt.text(value, index, str(value), va='center', ha='right', color='white', fontsize=11)

# Customize the plot
plt.xlabel('Accurate Passes Percentage')
plt.ylabel('Player - Year')
plt.title('Top 10 Players by Accurate Passes Percentage per Edition of FIFA World Cup')

# Show the plot
plt.show()

# %%
# Sort the DataFrame by the 'keyPasses' column in descending order and take only the top 10 rows
df_top_10_key_passes = df.sort_values(by='keyPasses', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='keyPasses', y='Player_Year', hue='team', data=df_top_10_key_passes, palette=team_colors, legend=False)

# Add the value inside each bar
for index, value in enumerate(df_top_10_key_passes['keyPasses']):
    plt.text(value, index, str(value), va='center', ha='right', color='white', fontsize=11)

# Customize the plot
plt.xlabel('Key Passes')
plt.ylabel('Player - Year')
plt.title('Top 10 Players by Key Passes per Edition of FIFA World Cup')

# Show the plot
plt.show()

# %%
# Sort the DataFrame by the 'accurateFinalThirdPasses' column in descending order and take only the top 10 rows
df_top_10_final_third_passes = df.sort_values(by='accurateFinalThirdPasses', ascending=False).head(10)

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='accurateFinalThirdPasses', y='Player_Year', hue='team', data=df_top_10_final_third_passes, palette=team_colors, legend=False)

# Add the value inside each bar
for index, value in enumerate(df_top_10_final_third_passes['accurateFinalThirdPasses']):
    plt.text(value, index, str(value), va='center', ha='right', color='white', fontsize=11)

# Customize the plot
plt.xlabel('Accurate Final Third Passes')
plt.ylabel('Player - Year')
plt.title('Top 10 Players by Accurate Final Third Passes per Edition of FIFA World Cup')

# Show the plot
plt.show()

# %% [markdown]
# # After analysis
# This will lead me to analyze the results splited by metric in order to understand better which player was more dominant in every aspect considered during the analysis.

# %%
#Loading dataset
df_final = pd.read_csv('FWC_Stats3.csv')
df_final.head(5)
# Out:
#               player       team  year  Definitions     Duels    Passes  \
# 0       Lionel Messi  Argentina  2022           11  0.119123  0.636251
# 1     Enzo Fernández  Argentina  2022            2  0.233453  0.439058
# 2  Antoine Griezmann     France  2018            6  0.130433  0.350282
# 3      Kylian Mbappé     France  2018            4  0.245466  0.305577
# 4         Paul Pogba     France  2018            1  0.241002  0.386230
#
#    Dribbling  Defense  Opportunities  Discipline  OffensivePlay  Participation
# 0  15.668792      2.5       0.497030        -3.2       0.604653            1.0
# 1   3.681901     21.0       0.204809        -2.3       0.161607            1.0
# 2   8.219486      9.0       0.118812        -1.8       0.414753            1.0
# 3  23.483023      6.0       0.198586        -0.7       0.280417            1.0
# 4  10.040951     25.0       0.188967        -4.4       0.144651            1.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a color dictionary to map each team to a single color
team_colors = {team: color_palette[0] for team, color_palette in paletas_paises_campeones.items()}

# Get all numerical columns starting from the third column
columns_to_plot = df_final.iloc[:, 3:].select_dtypes(include=['float64', 'int64']).columns

# Loop over each column
for column in columns_to_plot:
    # Sort the DataFrame by the current column in descending order and take only the top 10 rows
    df_top_10 = df_final.sort_values(by=column, ascending=False).head(10)
    
    # Create a bar plot using Seaborn
    plt.figure(figsize=(12, 8))
    sns.barplot(x=column, y='player', hue='team', data=df_top_10, palette=team_colors, dodge=False)
    
    # Add the value inside each bar
    for index, value in enumerate(df_top_10[column]):
        plt.text(value, index, str(value), va='center', ha='right', color='white', fontsize=11)
    
    # Customize the plot
    plt.xlabel(column.capitalize())  # Capitalize the column name for the x-axis label
    plt.ylabel('Player - Year')
    plt.title(f'Top 10 Players by {column.capitalize()} per Edition of FIFA World Cup')
    plt.legend(loc='lower right')  # Move the legend to the lower right
    
    # Show the plot
    plt.show()
